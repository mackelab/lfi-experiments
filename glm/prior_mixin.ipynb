# %%
import delfi.distribution as dd
import delfi.generator as dg
import delfi.inference as infer
import delfi.utils.io as io
import delfi.summarystats as ds
import lfimodels.glm.utils as utils
import matplotlib.pyplot as plt
import numpy as np

from lfimodels.glm.GLM import GLM
from lfimodels.glm.GLMStats import GLMStats
from delfi.utils.viz import plot_pdf

# %matplotlib inline

# %%
seed = 42
m = GLM(seed=seed)


alphas = [ 0.01 ]
runs = {}
for alpha in alphas:
    p = utils.smoothing_prior(n_params=m.n_params, seed=seed)
    s = GLMStats(n_summary=m.n_params)
    g = dg.Default(model=m, prior=p, summary=s)

    true_params, labels_params = utils.obs_params()
    obs = utils.obs_data(true_params, seed=seed)
    obs_stats = utils.obs_stats(true_params, seed=seed)

    rerun = False  # if False, will try loading file from disk

    try:
        assert rerun == False, 'rerun requested'
        sam = np.load('sam.npz')['arr_0']
    except:
        sam = utils.pg_mcmc(true_params, obs)
        np.savez('sam.npz', sam)

    seed = 99
    g = dg.Default(model=m, prior=p, summary=s)
    
    res = infer.SNPE(g, 
                     obs=obs_stats, 
                     convert_to_T=None,
                     n_hiddens=[50], 
                     seed=seed, 
                     pilot_samples=1000,
                     svi=True,
                     reg_lambda=0.01,
                     prior_mixin=alpha,
                     prior_norm=False)

    logs, tds, posteriors = res.run(n_train=5000, 
                                    n_rounds=5, 
                                    minibatch=100, 
                                    epochs=1000, 
                                    round_cl=3)
    
    runs[alpha] = { 'logs' : logs, 'tds' : tds, 'posteriors' : posteriors }
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %% [markdown]
# ## SNPE

# %%
for alpha in alphas:
    posteriors = runs[alpha]['posteriors']
    for r in range(5):
        posterior = posteriors[r]
        fig, ax = plot_pdf(posterior.xs[0], 
                           lims=[-2,2], 
                           samples=sam, 
                           gt=true_params, 
                           figsize=(9,9));
        
        
        plt.savefig('glm_posterior_alpha_{}_r_{}.pdf'.format(alpha, r))
        
    # save results
    #import pickle
    #with open('glm_posterior_alpha_{}.pkl'.format(alpha),'wb') as handle:
    #    pickle.dump(posteriors, handle)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6778b36bbc43> in <module>()
#      10
#      11
# ---> 12         plt.savefig('glm_posterior_alpha_{}_r_{}.pdf'.format(alpha, r))
#      13
#      14     # save results
#
# /usr/local/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     696     fig = gcf()
#     697     res = fig.savefig(*args, **kwargs)
# --> 698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#     700
#
# /usr/local/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2038         if not self._is_idle_drawing:
#    2039             with self._idle_draw_cntx():
# -> 2040                 self.draw(*args, **kwargs)
#    2041
#    2042     def draw_cursor(self, event):
#
# /usr/local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /usr/local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /usr/local/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1142
#    1143             mimage._draw_list_compositing_images(
# -> 1144                 renderer, self, dsu, self.suppressComposite)
#    1145
#    1146             renderer.close_group('figure')
#
# /usr/local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /usr/local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2424             renderer.stop_rasterizing()
#    2425
# -> 2426         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2427
#    2428         renderer.close_group('axes')
#
# /usr/local/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /usr/local/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /usr/local/lib/python3.6/site-packages/matplotlib/patches.py in draw(self, renderer)
#     563
#     564         path = self.get_path()
# --> 565         transform = self.get_transform()
#     566         tpath = transform.transform_path_non_affine(path)
#     567         affine = transform.get_affine()
#
# /usr/local/lib/python3.6/site-packages/matplotlib/patches.py in get_transform(self)
#     218         to the :class:`Patch`.
#     219         """
# --> 220         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     221
#     222     def get_data_transform(self):
#
# /usr/local/lib/python3.6/site-packages/matplotlib/patches.py in get_patch_transform(self)
#     718
#     719     def get_patch_transform(self):
# --> 720         self._update_patch_transform()
#     721         return self._rect_transform
#     722
#
# /usr/local/lib/python3.6/site-packages/matplotlib/patches.py in _update_patch_transform(self)
#     712         height = self.convert_yunits(self._height)
#     713         bbox = transforms.Bbox.from_bounds(x, y, width, height)
# --> 714         rot_trans = transforms.Affine2D()
#     715         rot_trans.rotate_deg_around(x, y, self._angle)
#     716         self._rect_transform = transforms.BboxTransformTo(bbox)
#
# KeyboardInterrupt:

# %% [markdown]
# ## CDELFI

# %%
import delfi.distribution as dd
import delfi.generator as dg
import delfi.inference as infer
import delfi.utils.io as io
import delfi.summarystats as ds
import lfimodels.glm.utils as utils
import matplotlib.pyplot as plt
import numpy as np

from lfimodels.glm.GLM import GLM
from lfimodels.glm.GLMStats import GLMStats
from delfi.utils.viz import plot_pdf

# %matplotlib inline

seed = 42
m = GLM(seed=seed)
p = utils.smoothing_prior(n_params=m.n_params, seed=seed)
s = GLMStats(n_summary=m.n_params)
g = dg.Default(model=m, prior=p, summary=s)

true_params, labels_params = utils.obs_params()
obs = utils.obs_data(true_params, seed=seed)
obs_stats = utils.obs_stats(true_params, seed=seed)

rerun = False  # if False, will try loading file from disk

try:
    assert rerun == False, 'rerun requested'
    sam = np.load('sam.npz')['arr_0']
except:
    sam = utils.pg_mcmc(true_params, obs)
    np.savez('sam.npz', sam)
    
seed = 99
g = dg.Default(model=m, prior=p, summary=s)
res = infer.CDELFI(g, 
                   obs=obs_stats, 
                   n_hiddens=[50], 
                   seed=seed, 
                   pilot_samples=1000,
                   svi=True,
                   reg_lambda=0.01,
                   prior_norm=False)

logs, tds, posteriors = res.run(n_train=5000, 
                                n_rounds=5, 
                                minibatch=100, 
                                epochs=1000)
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
for r in range(5):
    posterior = posteriors[r]
    plot_pdf(posterior.xs[0], 
             lims=[-2,2], 
             samples=sam, 
             gt=true_params, 
             figsize=(9,9));

# %%
"""
# save posteriors
posterior = posteriors[-1]
import pickle
with open('/home/jm/Mackelab/team/Write/Manuscripts/2017_NIPS_NeuralModelInference/figs/glm_posterior_cdelfi.pkl','wb') as handle:
    pickle.dump(posterior, handle)
"""

# %% [markdown]
# ## Version info

# %%
# !cd /home/jm/repos/delfi/; git rev-parse origin/master
# Out:
# d3966254abdce44f401c2d5ff169e005534323b6

# %%
# !cd /home/jm/repos/lfi-models/; git rev-parse origin/master
# Out:
# 0b4ac370e991439298aef7f176478ffc6eab3f31

# %%
import matplotlib
matplotlib.__version__
# Out:
# '2.1.0'
